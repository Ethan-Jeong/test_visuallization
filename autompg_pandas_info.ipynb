# %% [markdown]
# <a href="https://colab.research.google.com/github/Ethan-Jeong/test_visuallization/blob/master/autompg_pandas_info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /content

# %%
# !ls -l ./auto-mpg_1.csv
# Out:
# -rw-r--r-- 1 root root 21913 Jul  5 01:30 ./auto-mpg_1.csv

# %%
df = pd.read_csv('./auto-mpg_1.csv',header=None)

# %%
df.info() # DataFrame 정보 확인

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.describe() # DataFrame 통계 정보

# %%
df[3].describe() # 3 컬럼에 대한 DataFrame 통계 정보

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df[8].describe() # 3 컬럼에 대한 DataFrame 통계 정보

# %%
df[0].mean() # 0 컬럼 평균 데이터
# Out:
# 23.514572864321615

# %%
df[0].std() # 0 컬럼의 std 값
# Out:
# 7.815984312565782

# %%
df[0].count() # 0 컬럼의 수량
# Out:
# 398

# %%
df[0].min() # 0 컬럼의 최소값
# Out:
# 9.0

# %%
df[0].max() # 0 컬럼의 최대값
# Out:
# 46.6
